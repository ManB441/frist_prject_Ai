# %%
# =========================
# PROJECT 1: REGRESSION
# =========================

import pandas as pd

df = pd.read_csv("data.csv")

df.head()
# Out:
#    Hours  Scores
# 0    1.0      17
# 1    2.0      21
# 2    2.5      24
# 3    3.0      33
# 4    3.5      35

# %%
import matplotlib.pyplot as plt
plt.scatter(df["Hours"],df["Scores"])
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x=df[["Hours"]]
y=df["Scores"]
x_train ,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
model=LinearRegression()
model.fit(x_train,y_train)

predictions=model.predict(x_test)
print(predictions)
# Out:
# [80.29733359 27.96969116 32.33032803 36.6909649 ]

# %%
import pandas as pd

new_data = pd.DataFrame([[5]], columns=["Hours"])
model.predict(new_data)
# Out:
# array([49.7728755])

# %%
from sklearn.metrics import mean_absolute_error 
error =mean_absolute_error (y_test,predictions)
print(error)
# Out:
# 1.6569154037981964

# %%
plt.scatter(df["Hours"],df["Scores"])
plt.plot(x,model.predict(x))
plt.show()

# %%
import pandas as pd

new_data = pd.DataFrame([[5]], columns=["Hours"])
print(model.predict(new_data))
# Out:
# [49.7728755]

# %%
df["Result"]=df["Scores"].apply(lambda x : 1 if x >= 50 else 0)
df.head()
# Out:
#    Hours  Scores  Result
# 0    1.0      17       0
# 1    2.0      21       0
# 2    2.5      24       0
# 3    3.0      33       0
# 4    3.5      35       0

# %%
x=df[["Hours"]]
y=df["Result"]

# %%
from sklearn.model_selection import train_test_split
x_train ,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
model =LogisticRegression()
model.fit(x_train,y_train)
predictions=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, predictions)
print(accuracy)
# Out:
# 0.75

# %%
import pandas as pd

print(model.predict(pd.DataFrame([[4]], columns=["Hours"])))
print(model.predict(pd.DataFrame([[8]], columns=["Hours"])))
# Out:
# [0]
# [1]
